# %%
import pandas as pd

# %%
mainpath = '/Users/armanimanov/Downloads/abcd_p_demo.csv'

data = pd.read_csv(mainpath)

filtered_data = data[data['eventname'] == '2_year_follow_up_y_arm_1']

# %%
filtered_data
# Out:
#          src_subject_id                 eventname  \
# 2      NDAR_INV003RTV85  2_year_follow_up_y_arm_1
# 6      NDAR_INV005V6D2C  2_year_follow_up_y_arm_1
# 13     NDAR_INV00BD7VDC  2_year_follow_up_y_arm_1
# 16     NDAR_INV00CY2MDM  2_year_follow_up_y_arm_1
# 21     NDAR_INV00HEV6HB  2_year_follow_up_y_arm_1
# ...                 ...                       ...
# 48782  NDAR_INVZZLZCKAY  2_year_follow_up_y_arm_1
# 48787  NDAR_INVZZNX6W2P  2_year_follow_up_y_arm_1
# 48792  NDAR_INVZZPKBDAC  2_year_follow_up_y_arm_1
# 48797  NDAR_INVZZZ2ALR6  2_year_follow_up_y_arm_1
# 48804  NDAR_INVZZZP87KR  2_year_follow_up_y_arm_1
#
#        demoi_p_select_language___1  demo_prim  demo_brthdat_v2  demo_ed_v2  \
# 2                                0        NaN              NaN         NaN
# 6                                0        NaN              NaN         NaN
# 13                               0        NaN              NaN         NaN
# ...
